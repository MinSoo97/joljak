# %%
import pyzbar.pyzbar as pyzbar
import cv2
import matplotlib.pyplot as plt

print(cv2.__version__)
# Out:
# 4.5.1

# %%
img = cv2.imread('10.jpg')

plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')

# %%
decoded = pyzbar.decode(gray)

decoded
# Out:
# [Decoded(data=b'8801062521487', type='EAN13', rect=Rect(left=1437, top=1810, width=930, height=298), polygon=[Point(x=1437, y=2071), Point(x=1437, y=2083), Point(x=2364, y=2108), Point(x=2365, y=2090), Point(x=2367, y=1882), Point(x=2367, y=1810), Point(x=1442, y=1811), Point(x=1441, y=1847)])]

# %%
for d in decoded:
    print(d.data)
    
    cv2.rectangle(img, (d.rect[0],d.rect[1]),(d.rect[0]+d.rect[2],d.rect[1]+d.rect[3]),(0,255,0),10)

plt.figure(figsize=(10, 8))
plt.imshow(img)
# Out:
# b'8801062521487'

# %%
8801062521487
